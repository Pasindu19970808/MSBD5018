# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from itertools import chain
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import OneHotEncoder
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from scipy.sparse import coo_matrix
stopwords = set(stopwords.words("english"))
ps = PorterStemmer()
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import regex as re
from sklearn.metrics import precision_score,recall_score,f1_score,accuracy_score

# %%
import nltk
nltk.download ('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### Data Loader

# %% [markdown]
# Python provides a lot of packages to load files in different formats. We provide a simple data loader to help you load .csv files.

# %%
def load_data(file_name):
    """
    :param file_name: a file name, type: str
    return a list of ids, a list of reviews, a list of labels
    https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
    """
    df = pd.read_csv(file_name)

    return df['id'], df["text"], df['label']

def load_labels(file_name):
    """
    :param file_name: a file name, type: str
    return a list of labels
    """
    return pd.read_csv(file_name)['label']

def write_predictions(file_name, pred):
    df = pd.DataFrame(zip(range(len(pred)), pred))
    df.columns = ["id", "label"]
    df.to_csv(file_name, index=False)

# %% [markdown]
# ### Feature Extractor

# %% [markdown]
# The **feature extractor** is one of the most important parts in a pipeline.
# We will use the text pre-processing techniques you have learnt from the previous tutorials as the feature extractor.

# %%
def tokenize(text):
    """
    :param text: a doc with multiple sentences, type: str
    return a word list, type: list
    e.g.
    Input: 'Text mining is to identify useful information.'
    Output: ['Text', 'mining', 'is', 'to', 'identify', 'useful', 'information', '.']
    """
    return nltk.word_tokenize(text)

# %%
def stem(tokens):
    """
    :param tokens: a list of tokens, type: list
    return a list of stemmed words, type: list
    e.g.
    Input: ['Text', 'mining', 'is', 'to', 'identify', 'useful', 'information', '.']
    Output: ['text', 'mine', 'is', 'to', 'identifi', 'use', 'inform', '.']
    """
    ### equivalent code
    # results = list()
    # for token in tokens:
    #     results.append(ps.stem(token))
    # return results

    return [ps.stem(token) for token in tokens]

# %%
def lemmatize(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

# %%
def n_gram(tokens, n=1):
    """
    :param tokens: a list of tokens, type: list
    :param n: the corresponding n-gram, type: int
    return a list of n-gram tokens, type: list
    e.g.
    Input: ['text', 'mine', 'is', 'to', 'identifi', 'use', 'inform', '.'], 2
    Output: ['text mine', 'mine is', 'is to', 'to identifi', 'identifi use', 'use inform', 'inform .']
    """
    if n == 1:
        return tokens
    else:
        results = list()
        for i in range(len(tokens)-n+1):
            # tokens[i:i+n] will return a sublist from i th to i+n th (i+n th is not included)
            results.append(" ".join(tokens[i:i+n]))
        return results

# %%
def filter_stopwords(tokens):
    """
    :param tokens: a list of tokens, type: list
    return a list of filtered tokens, type: list
    e.g.
    Input: ['text', 'mine', 'is', 'to', 'identifi', 'use', 'inform', '.']
    Output: ['text', 'mine', 'identifi', 'use', 'inform', '.']
    """
    ### equivalent code
    # results = list()
    # for token in tokens:
    #     if token not in stopwords and not token.isnumeric():
    #         results.append(token)
    # return results

    return [token for token in tokens if token not in stopwords and not token.isnumeric()]

# %%
def get_onehot_vector(feats, feats_dict):
    """
    :param feats: a list of features, type: list
    :param feats_dict: a dict from features to indices, type: dict
    return a feature vector,
    """
    # initialize the vector as all zeros
    vector = np.zeros(len(feats_dict), dtype=np.float)
    for f in feats:
        # get the feature index, return -1 if the feature is not existed
        f_idx = feats_dict.get(f, -1)
        if f_idx != -1:
            # set the corresponding element as 1
            vector[f_idx] = 1
    return vector

# %% [markdown]
# ### Classifier

# %% [markdown]
# In this tutorial, we use the Naive Bayes algorithm a black-box classifier to illustrate the classification pipeline.
#
# If you want to know more about the model, you can check this web page https://scikit-learn.org/stable/modules/naive_bayes.html .

# %% [markdown]
# ### Connect All Parts

# %% [markdown]
# Now we have the data loader, feature extractor, and the classifier. We can connect them to finish this pipeline of classification.

# %%
train_file = "./data/train.csv"
test_file = "./data/test.csv"
ans_file = "./data/answer.csv"
pred_file = "./data/pred.csv"

# load data
train_ids, train_texts, train_labels = load_data(train_file)
test_ids, test_texts, _ = load_data(test_file)
test_labels = load_labels(ans_file)

# %% [markdown]
# Extract Features

# %%
# tokenization
# gives a list of tokens
train_tokens = [tokenize(text) for text in train_texts] 
test_tokens = [tokenize(text) for text in test_texts]

# %% [markdown]
# Remove punctuation from train and test tokens

# %%
regpat = re.compile(r"[A-Za-z0-9\s]+")
train_tokens_removed = [[i for i in tokens if regpat.search(i) == None] for tokens in train_tokens]
test_tokens_removed = [[i for i in tokens if regpat.search(i) == None] for tokens in test_tokens]
train_tokens = [[i for i in tokens if regpat.search(i)] for tokens in train_tokens]
test_tokens =  [[i for i in tokens if regpat.search(i)] for tokens in test_tokens]

# %%
# stemming
train_stemmed = [lemmatize(tokens) for tokens in train_tokens]
test_stemmed = [lemmatize(tokens) for tokens in test_tokens]

# %% [markdown]
# Getting n-grams : How to combine n-grams into the vocabulary?
#
# Simply add them to the rest of the vocabulary

# %%
# n-gram : Need to be made on stemmed/lemmatized tokens
train_2_gram = [n_gram(tokens, 2) for tokens in train_stemmed]
train_3_gram = [n_gram(tokens, 3) for tokens in train_stemmed]
train_4_gram = [n_gram(tokens, 4) for tokens in train_stemmed]

test_2_gram = [n_gram(tokens, 2) for tokens in test_stemmed]
test_3_gram = [n_gram(tokens, 3) for tokens in test_stemmed]
test_4_gram = [n_gram(tokens, 4) for tokens in test_stemmed]

# %%
# remove stopwords
# the input should be the stemmed tokens and the output is a cleanner token list
train_stemmed = [filter_stopwords(tokens) for tokens in train_stemmed]
test_stemmed = [filter_stopwords(tokens) for tokens in test_stemmed]

# %% [markdown]
# We only use those features which occur more than 10 times

# %%
# build a set containing each unique feature which has appeared more than 10 times in the training set
feats_set = set()

# build a Counter for stemmed features, e.g., {"text": 2, "mine": 1}
stemmed_feat_cnt = Counter()

for feats in train_stemmed:
    stemmed_feat_cnt.update(feats)

# add those stem features which occurs more than 10 times into the feature set.
feats_set.update([f for f, cnt in stemmed_feat_cnt.items() if cnt > 10])

# %%
# build a Counter for 2-gram features
bi_gram_feat_cnt = Counter()
for feats in train_2_gram:
    bi_gram_feat_cnt.update(feats)

#the n-grams are added to the same feature set
# add those 2-gram features which occurs more than 10 times into the feature set.
feats_set.update([f for f, cnt in bi_gram_feat_cnt.items() if cnt > 10]) 


# build a Counter for 3-gram features
tri_gram_feat_cnt = Counter()

for feats in train_3_gram:
    tri_gram_feat_cnt.update(feats)

# add those 3-gram features which occurs more than 10 times into the feature set.
feats_set.update([f for f, cnt in tri_gram_feat_cnt.items() if cnt > 10]) 


# first, build a Counter for 4-gram features
four_gram_feat_cnt = Counter()

for feats in train_4_gram:
    four_gram_feat_cnt.update(feats)
    
# add those 4-gram features which occurs more than 10 times into the feature set.
feats_set.update([f for f, cnt in four_gram_feat_cnt.items() if cnt > 10]) 


print("Size of features:", len(feats_set))

# build the feature dict mapping each feature to its index 
feats_dict = dict(zip(feats_set, range(len(feats_set))))
# Out:
# Size of features: 3053

# %%
# build the feature list
train_feats = list()
for i in range(len(train_ids)):
    # concatenate the stemmed token list and all n-gram list together
    train_feats.append(train_stemmed[i] + train_2_gram[i] + train_3_gram[i] + train_4_gram[i])
test_feats = list()
for i in range(len(test_ids)):
    # concatenate the stemmed token list and all n-gram list together
    test_feats.append(test_stemmed[i] + test_2_gram[i]+ test_3_gram[i] + test_4_gram[i])

# %%
#COVERTING TO A SPARSE COO MATRIX AND GETTING THE STORED COORDINATES
# test = coo_matrix(np.vstack([get_onehot_vector(feats,feats_dict) for feats in train_feats]))
# [(r,c) for r,c in zip(test.row,test.col)]

# %%
# build the feats_matrix
# We first convert each example to a ont-hot vector, and then stack vectors as a matrix. Afterwards,
# we save this feature matirx in a COO sparse matrix format to reduce memory consumption.
# See https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.coo_matrix.html and 
# https://en.wikipedia.org/wiki/Sparse_matrix#Coordinate_list_(COO) for details.
train_feats_matrix = coo_matrix(np.vstack([get_onehot_vector(f, feats_dict) for f in train_feats]))
test_feats_matrix = coo_matrix(np.vstack([get_onehot_vector(f, feats_dict) for f in test_feats]))

# %%
def calculate_metrics(y_true,y_pred,precision,recall,f1,accuracy):
    precision += precision_score(y_true,y_pred,average = 'weighted')
    recall += recall_score(y_true,y_pred,average = 'weighted')
    f1 += f1_score(y_true,y_pred,average = 'weighted')
    accuracy += accuracy_score(y_true,y_pred)
    return precision,recall,f1,accuracy

# %%
kfoldsplitter = StratifiedKFold(n_splits=5,random_state=42,shuffle=True)
labels = train_labels.values
train_array = train_feats_matrix.toarray()
precision_val,recall_val,f1_val,acc_val = 0,0,0,0
precision_train,recall_train,f1_train,acc_train = 0,0,0,0

for train_index,val_index in kfoldsplitter.split(train_array,labels):
    #get training and validation data/labels
    train_data = train_array[train_index]
    train_y = labels[train_index]
    val_data = train_array[val_index]
    val_y = labels[val_index]
    #fit classifier
    clf = GaussianNB()
    clf.fit(train_data,train_y)
    #do prediction
    res_y = clf.predict(val_data)
    train_res_y = clf.predict(train_data)
    #get metrics
    precision_val,recall_val,f1_val,acc_val = calculate_metrics(val_y,res_y,precision_val,recall_val,f1_val,acc_val)
    precision_train,recall_train,f1_train,acc_train = calculate_metrics(train_res_y,train_y,precision_train,recall_train,f1_train,acc_train)
precision_val /= 5
recall_val /= 5
f1_val /= 5
acc_val /= 5

precision_train /= 5
recall_train /= 5
f1_train /= 5
acc_train /= 5

print(f"Training : Precision : {precision_train}, Recall : {recall_train}, F1 : {f1_train}, Accuracy : {acc_train}")

print(f"Validation : Precision : {precision_val}, Recall : {recall_val}, F1 : {f1_val}, Accuracy : {acc_val}")
# Out:
# 0
# 1
# 2
# 3
# 4
# Training : Precision : 0.8754016966457397, Recall : 0.859125, F1 : 0.8594381723193187, Accuracy : 0.859125
# Validation : Precision : 0.399536134881071, Recall : 0.42000000000000004, F1 : 0.3890461298931594, Accuracy : 0.42000000000000004

# %%
# Fit the feature matrix and labels to train the classifier.
# Since the classifier can only process matrices in the dense format,
# we use toarray() function to get the dense representation of the sparse 
# matrix before passing it to the classifier
# clf0.fit(train_feats_matrix.toarray(), train_labels.values)

# %% [markdown]
# Evaluate the classifier on train and test set

# %%
#Get the predictions of the classifier
# train_pred = clf0.predict(train_feats_matrix.toarray())
# test_pred = clf0.predict(test_feats_matrix.toarray())

# #Compute accuracy scores
# train_score = accuracy_score(train_labels.values, train_pred)
# test_score = accuracy_score(test_labels.values, test_pred)
# print("training accuracy", train_score)
# print("test accuracy", test_score)

# %% [markdown]
# We can see that the training accuracy is much lower than the test accuracy, which indicates that our classifier is overfitted.
# In order to address this overfitting issue, we can use the cross-validation with ensemble to select the best input features.
# We will first analyze the features, then we will introduce how to use the cross-validation and ensemble technique.

# %% [markdown]
# ### Feature Analysis

# %% [markdown]
# Firstly, we can check the stemmed features.

# %%
# get feature size
print("stemmed feature size:", len(stemmed_feat_cnt))

# then, get the sorted features by the frequency
stemmed_feat_keys = [f for f,cnt in stemmed_feat_cnt.most_common()]

# draw linear lines and log lines for sorted features
# set the figure size
plt.figure(figsize=(10,4))
# generate two subfigures and set current as the first one
plt.subplot(1,2,1)
# draw linear lines
plt.plot(range(1, len(stemmed_feat_cnt)+1), 
        [stemmed_feat_cnt[f] for f in stemmed_feat_keys])
# set labels
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
# set current as the second one
plt.subplot(1,2,2)
# draw log lines
plt.loglog(range(1, len(stemmed_feat_cnt)+1), 
           [stemmed_feat_cnt[f] for f in stemmed_feat_keys],
           basex=10, basey=10)
# set labels
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
plt.show()
# Out:
# stemmed feature size: 14745
# <ipython-input-30-c9ff4a25f9bc>:21: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(stemmed_feat_cnt)+1),
# <ipython-input-30-c9ff4a25f9bc>:21: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(stemmed_feat_cnt)+1),

# %% [markdown]
# Similarly, we can check the 2-gram features.

# %%
# get the feature size
print("2-gram feature size:", len(bi_gram_feat_cnt))

# then, get the sorted features by the frequency
bi_gram_feat_keys = [f for f,cnt in bi_gram_feat_cnt.most_common()]

# draw linear lines and log lines for sorted features
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(range(1, len(bi_gram_feat_cnt)+1), 
        [bi_gram_feat_cnt[f] for f in bi_gram_feat_keys])
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
plt.subplot(1,2,2)
plt.loglog(range(1, len(bi_gram_feat_cnt)+1), 
            [bi_gram_feat_cnt[f] for f in bi_gram_feat_keys],
           basex=10, basey=10)
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
plt.show()
# Out:
# 2-gram feature size: 112763
# <ipython-input-31-6af45c2f514a>:15: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(bi_gram_feat_cnt)+1),
# <ipython-input-31-6af45c2f514a>:15: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(bi_gram_feat_cnt)+1),

# %% [markdown]
# 3-gram features are much sparser.

# %%
tri_gram_feat_cnt
# Out:
# Counter({'nice hotel expensive': 1,
#          'hotel expensive parking': 1,
#          'expensive parking got': 1,
#          'parking got good': 1,
#          'got good deal': 5,
#          'good deal stay': 1,
#          'deal stay hotel': 1,
#          'stay hotel anniversary': 1,
#          'hotel anniversary arrived': 1,
#          'anniversary arrived late': 1,
#          'arrived late evening': 2,
#          'late evening took': 1,
#          'evening took advice': 1,
#          'took advice previous': 1,
#          'advice previous review': 1,
#          'previous review did': 1,
#          'review did valet': 1,
#          'did valet parking': 1,
#          'valet parking check': 1,
#          'parking check quick': 1,
#          'check quick easy': 1,
#          'quick easy little': 1,
#          'easy little disappointed': 1,
#          'little disappointed non-existent': 1,
#          'disappointed non-existent view': 1,
#          'non-existent view room': 1,
#          'view room room': 3,
#          'room room clean': 2,
#          'room clean nice': 2,
#          'clean nice size': 1,
#          'nice size bed': 1,
#          'size bed comfortable': 6,
#          'bed comfortable woke': 1,
#          'comfortable woke stiff': 1,
#          'woke stiff neck': 1,
#          'stiff neck high': 1,
#          'neck high pillow': 1,
#          'high pillow not': 1,
#          'pillow not soundproof': 1,
#          'not soundproof like': 1,
#          'soundproof like heard': 1,
#          'like heard music': 1,
#          'heard music room': 1,
#          'music room night': 2,
#          'room night morning': 1,
#          'night morning loud': 1,
#          'morning loud bang': 1,
#          'loud bang door': 1,
#          'bang door opening': 1,
#          'door opening closing': 1,
#          'opening closing hear': 1,
#          'closing hear people': 1,
#          'hear people talking': 4,
#          'people talking hallway': 1,
#          'talking hallway maybe': 1,
#          'hallway maybe just': 1,
#          'maybe just noisy': 1,
#          'just noisy neighbor': 1,
#          'noisy neighbor aveda': 1,
#          'neighbor aveda bath': 1,
#          'aveda bath product': 2,
#          'bath product nice': 1,
#          'product nice did': 1,
#          'nice did not': 2,
#          'did not goldfish': 1,
#          'not goldfish stay': 1,
#          'goldfish stay nice': 1,
#          'stay nice touch': 1,
#          'nice touch taken': 1,
#          'touch taken advantage': 1,
#          'taken advantage staying': 1,
#          'advantage staying longer': 1,
#          'staying longer location': 1,
#          'longer location great': 1,
#          'location great walking': 3,
#          'great walking distance': 1,
#          'walking distance shopping': 5,
#          'distance shopping overall': 1,
#          'shopping overall nice': 1,
#          'overall nice experience': 2,
#          'nice experience having': 1,
#          'experience having pay': 1,
#          'having pay 40': 1,
#          'pay 40 parking': 1,
#          '40 parking night': 1,
#          'ok nothing special': 3,
#          'nothing special charge': 1,
#          'special charge diamond': 1,
#          'charge diamond member': 1,
#          'diamond member hilton': 1,
#          'member hilton decided': 1,
#          'hilton decided chain': 1,
#          'decided chain shot': 1,
#          'chain shot 20th': 1,
#          'shot 20th anniversary': 1,
#          '20th anniversary seattle': 1,
#          'anniversary seattle start': 1,
#          'seattle start booked': 1,
#          'start booked suite': 1,
#          'booked suite paid': 1,
#          'suite paid extra': 1,
#          'paid extra website': 1,
#          'extra website description': 1,
#          'website description not': 1,
#          'description not suite': 1,
#          'not suite bedroom': 1,
#          'suite bedroom bathroom': 1,
#          'bedroom bathroom standard': 1,
#          'bathroom standard hotel': 1,
#          'standard hotel room': 1,
#          'hotel room took': 1,
#          'room took printed': 1,
#          'took printed reservation': 1,
#          'printed reservation desk': 1,
#          'reservation desk showed': 1,
#          'desk showed said': 1,
#          'showed said thing': 1,
#          'said thing like': 1,
#          'thing like tv': 1,
#          'like tv couch': 1,
#          'tv couch ect': 1,
#          'couch ect desk': 1,
#          'ect desk clerk': 1,
#          'desk clerk told': 2,
#          'clerk told oh': 1,
#          'told oh mixed': 1,
#          'oh mixed suite': 1,
#          'mixed suite description': 1,
#          'suite description kimpton': 1,
#          'description kimpton website': 1,
#          'kimpton website sorry': 1,
#          'website sorry free': 1,
#          'sorry free breakfast': 1,
#          'free breakfast got': 1,
#          'breakfast got kidding': 1,
#          'got kidding embassy': 1,
#          'kidding embassy suit': 1,
#          'embassy suit sitting': 1,
#          'suit sitting room': 1,
#          'sitting room bathroom': 1,
#          'room bathroom bedroom': 1,
#          'bathroom bedroom unlike': 1,
#          'bedroom unlike kimpton': 1,
#          'unlike kimpton call': 1,
#          'kimpton call suite': 1,
#          'call suite 5': 1,
#          'suite 5 day': 1,
#          '5 day stay': 4,
#          'day stay offer': 1,
#          'stay offer correct': 1,
#          'offer correct false': 1,
#          'correct false advertising': 1,
#          'false advertising send': 1,
#          'advertising send kimpton': 1,
#          'send kimpton preferred': 1,
#          'kimpton preferred guest': 1,
#          'preferred guest website': 1,
#          'guest website email': 1,
#          'website email asking': 1,
#          'email asking failure': 1,
#          'asking failure provide': 1,
#          'failure provide suite': 1,
#          'provide suite advertised': 1,
#          'suite advertised website': 1,
#          'advertised website reservation': 1,
#          'website reservation description': 1,
#          'reservation description furnished': 1,
#          'description furnished hard': 1,
#          'furnished hard copy': 1,
#          'hard copy reservation': 1,
#          'copy reservation printout': 1,
#          'reservation printout website': 1,
#          'printout website desk': 1,
#          'website desk manager': 1,
#          'desk manager duty': 1,
#          'manager duty did': 1,
#          'duty did not': 1,
#          'did not reply': 1,
#          'not reply solution': 1,
#          'reply solution send': 1,
#          'solution send email': 1,
#          'send email trip': 1,
#          'email trip guest': 1,
#          'trip guest survey': 1,
#          'guest survey did': 1,
#          'survey did not': 1,
#          'did not follow': 1,
#          'not follow email': 1,
#          'follow email mail': 1,
#          'email mail guess': 1,
#          'mail guess tell': 1,
#          'guess tell concerned': 1,
#          'tell concerned guest.the': 1,
#          'concerned guest.the staff': 1,
#          'guest.the staff ranged': 1,
#          'staff ranged indifferent': 1,
#          'ranged indifferent not': 1,
#          'indifferent not helpful': 1,
#          'not helpful asked': 1,
#          'helpful asked desk': 1,
#          'asked desk good': 1,
#          'desk good breakfast': 1,
#          'good breakfast spot': 1,
#          'breakfast spot neighborhood': 1,
#          'spot neighborhood hood': 1,
#          'neighborhood hood told': 1,
#          'hood told no': 1,
#          'told no hotel': 1,
#          'no hotel gee': 1,
#          'hotel gee best': 1,
#          'gee best breakfast': 1,
#          'best breakfast spot': 1,
#          'breakfast spot seattle': 1,
#          'spot seattle 1/2': 1,
#          'seattle 1/2 block': 1,
#          '1/2 block away': 3,
#          'block away convenient': 2,
#          'away convenient hotel': 1,
#          'convenient hotel doe': 1,
#          'hotel doe not': 10,
#          'doe not know': 2,
#          'not know exist': 1,
#          'know exist arrived': 1,
#          'exist arrived late': 1,
#          'arrived late night': 2,
#          'late night 11': 1,
#          'night 11 pm': 1,
#          '11 pm inside': 1,
#          'pm inside run': 1,
#          'inside run bellman': 1,
#          'run bellman busy': 1,
#          'bellman busy chating': 1,
#          'busy chating cell': 1,
#          'chating cell phone': 1,
#          'cell phone help': 1,
#          'phone help bags.prior': 1,
#          'help bags.prior arrival': 1,
#          'bags.prior arrival emailed': 1,
#          'arrival emailed hotel': 1,
#          'emailed hotel inform': 1,
#          'hotel inform 20th': 1,
#          'inform 20th anniversary': 1,
#          '20th anniversary half': 1,
#          'anniversary half really': 1,
#          'half really picky': 1,
#          'really picky wanted': 1,
#          'picky wanted make': 1,
#          'wanted make sure': 3,
#          'make sure good': 4,
#          'sure good got': 1,
#          'good got nice': 1,
#          'got nice email': 1,
#          'nice email saying': 1,
#          'email saying like': 1,
#          'saying like deliver': 1,
#          'like deliver bottle': 1,
#          'deliver bottle champagne': 1,
#          'bottle champagne chocolate': 2,
#          'champagne chocolate covered': 1,
#          'chocolate covered strawberry': 3,
#          'covered strawberry room': 3,
#          'strawberry room arrival': 1,
#          'room arrival celebrate': 1,
#          'arrival celebrate told': 1,
#          'celebrate told needed': 1,
#          'told needed foam': 1,
#          'needed foam pillow': 1,
#          'foam pillow arrival': 1,
#          'pillow arrival no': 1,
#          'arrival no champagne': 1,
#          'no champagne strawberry': 1,
#          'champagne strawberry no': 1,
#          'strawberry no foam': 1,
#          'no foam pillow': 1,
#          'foam pillow great': 1,
#          'pillow great room': 1,
#          'great room view': 1,
#          'room view alley': 1,
#          'view alley high': 1,
#          'alley high rise': 1,
#          'high rise building': 1,
#          'rise building good': 1,
#          'building good not': 1,
#          'good not better': 2,
#          'not better housekeeping': 1,
#          'better housekeeping staff': 2,
#          'housekeeping staff cleaner': 1,
#          'staff cleaner room': 1,
#          'cleaner room property': 1,
#          'room property impressed': 1,
#          'property impressed left': 1,
#          'impressed left morning': 1,
#          'left morning shopping': 1,
#          'morning shopping room': 1,
#          'shopping room got': 1,
#          'room got short': 1,
#          'got short trip': 1,
#          'short trip 2': 1,
#          'trip 2 hour': 1,
#          '2 hour bed': 1,
#          'hour bed comfortable.not': 1,
#          'bed comfortable.not good': 1,
#          'comfortable.not good ac-heat': 1,
#          'good ac-heat control': 1,
#          'ac-heat control 4': 1,
#          'control 4 x': 1,
#          '4 x 4': 1,
#          'x 4 inch': 1,
#          '4 inch screen': 1,
#          'inch screen bring': 1,
#          'screen bring green': 1,
#          'bring green shine': 1,
#          'green shine directly': 1,
#          'shine directly eye': 1,
#          'directly eye night': 1,
#          'eye night light': 1,
#          'night light sensitive': 1,
#          'light sensitive tape': 1,
#          'sensitive tape controls.this': 1,
#          'tape controls.this not': 1,
#          'controls.this not 4': 1,
#          'not 4 start': 1,
#          '4 start hotel': 1,
#          'start hotel clean': 1,
#          'hotel clean business': 1,
#          'clean business hotel': 1,
#          'business hotel super': 1,
#          'hotel super high': 1,
#          'super high rate': 1,
#          'high rate better': 1,
#          'rate better chain': 1,
#          'better chain hotel': 2,
#          'chain hotel seattle': 1,
#          'nice room not': 2,
#          'room not 4': 1,
#          'not 4 experience': 1,
#          '4 experience hotel': 1,
#          'experience hotel monaco': 1,
#          'hotel monaco seattle': 2,
#          'monaco seattle good': 1,
#          'seattle good hotel': 1,
#          "good hotel n't": 1,
#          "hotel n't 4": 1,
#          "n't 4 level.positives": 1,
#          '4 level.positives large': 1,
#          'level.positives large bathroom': 1,
#          'large bathroom mediterranean': 1,
#          'bathroom mediterranean suite': 1,
#          'mediterranean suite comfortable': 1,
#          'suite comfortable bed': 1,
#          'comfortable bed pillowsattentive': 1,
#          'bed pillowsattentive housekeeping': 1,
#          'pillowsattentive housekeeping staffnegatives': 1,
#          'housekeeping staffnegatives ac': 1,
#          'staffnegatives ac unit': 1,
#          'ac unit malfunctioned': 1,
#          'unit malfunctioned stay': 1,
#          'malfunctioned stay desk': 1,
#          'stay desk disorganized': 1,
#          'desk disorganized missed': 1,
#          'disorganized missed 3': 1,
#          'missed 3 separate': 1,
#          '3 separate wakeup': 1,
#          'separate wakeup call': 1,
#          'wakeup call concierge': 1,
#          'call concierge busy': 1,
#          'concierge busy hard': 1,
#          'busy hard touch': 1,
#          'hard touch did': 1,
#          "touch did n't": 3,
#          "did n't provide": 1,
#          "n't provide guidance": 1,
#          'provide guidance special': 1,
#          'guidance special requests.tv': 1,
#          'special requests.tv hard': 1,
#          'requests.tv hard use': 1,
#          'hard use ipod': 1,
#          'use ipod sound': 1,
#          'ipod sound dock': 1,
#          'sound dock suite': 1,
#          'dock suite non': 1,
#          'suite non functioning': 1,
#          'non functioning decided': 1,
#          'functioning decided book': 1,
#          'decided book mediterranean': 1,
#          'book mediterranean suite': 1,
#          'mediterranean suite 3': 1,
#          'suite 3 night': 1,
#          '3 night weekend': 1,
#          'night weekend stay': 1,
#          'weekend stay 1st': 1,
#          'stay 1st choice': 1,
#          '1st choice rest': 1,
#          'choice rest party': 1,
#          'rest party filled': 1,
#          'party filled comparison': 1,
#          'filled comparison w': 1,
#          'comparison w spent': 1,
#          'w spent 45': 1,
#          'spent 45 night': 1,
#          '45 night larger': 1,
#          'night larger square': 1,
#          'larger square footage': 1,
#          'square footage room': 2,
#          'footage room great': 1,
#          'room great soaking': 1,
#          'great soaking tub': 1,
#          'soaking tub whirlpool': 2,
#          'tub whirlpool jet': 1,
#          'whirlpool jet nice': 1,
#          'jet nice shower.before': 1,
#          'nice shower.before stay': 1,
#          'shower.before stay hotel': 1,
#          'stay hotel arrange': 1,
#          'hotel arrange car': 1,
#          'arrange car service': 1,
#          'car service price': 1,
#          'service price 53': 1,
#          'price 53 tip': 1,
#          '53 tip reasonable': 1,
#          'tip reasonable driver': 1,
#          'reasonable driver waiting': 1,
#          'driver waiting arrival.checkin': 1,
#          'waiting arrival.checkin easy': 1,
#          'arrival.checkin easy downside': 1,
#          'easy downside room': 1,
#          'downside room picked': 1,
#          'room picked 2': 1,
#          'picked 2 person': 1,
#          '2 person jacuzi': 1,
#          'person jacuzi tub': 1,
#          'jacuzi tub no': 1,
#          'tub no bath': 1,
#          'no bath accessory': 1,
#          'bath accessory salt': 1,
#          'accessory salt bubble': 1,
#          'salt bubble bath': 1,
#          'bubble bath did': 1,
#          "bath did n't": 1,
#          "did n't stay": 3,
#          "n't stay night": 1,
#          'stay night got': 1,
#          'night got 12/1a': 1,
#          'got 12/1a checked': 1,
#          '12/1a checked voucher': 1,
#          'checked voucher bottle': 1,
#          'voucher bottle champagne': 1,
#          'bottle champagne nice': 1,
#          'champagne nice gesture': 1,
#          'nice gesture fish': 1,
#          'gesture fish waiting': 1,
#          'fish waiting room': 1,
#          'waiting room impression': 1,
#          'room impression room': 2,
#          'impression room huge': 1,
#          'room huge open': 1,
#          'huge open space': 1,
#          'open space felt': 1,
#          'space felt room': 1,
#          'felt room big': 1,
#          'room big tv': 1,
#          'big tv far': 1,
#          'tv far away': 1,
#          'far away bed': 1,
#          'away bed chore': 1,
#          'bed chore change': 1,
#          'chore change channel': 1,
#          'change channel ipod': 1,
#          'channel ipod dock': 1,
#          'ipod dock broken': 1,
#          'dock broken disappointing.in': 1,
#          'broken disappointing.in morning': 1,
#          'disappointing.in morning way': 1,
#          'morning way asked': 1,
#          'way asked desk': 1,
#          'asked desk check': 1,
#          'desk check thermostat': 1,
#          'check thermostat said': 1,
#          'thermostat said 65f': 1,
#          'said 65f 74': 1,
#          '65f 74 2': 1,
#          '74 2 degree': 1,
#          '2 degree warm': 1,
#          'degree warm try': 1,
#          'warm try cover': 1,
#          'try cover face': 1,
#          'cover face night': 1,
#          'face night bright': 1,
#          'night bright blue': 1,
#          'bright blue light': 1,
#          'blue light kept': 1,
#          'light kept got': 1,
#          'kept got room': 1,
#          'got room night': 1,
#          'room night no': 1,
#          'night no 1st': 1,
#          'no 1st drop': 1,
#          '1st drop desk': 1,
#          'drop desk called': 1,
#          'desk called maintainence': 1,
#          'called maintainence came': 1,
#          'maintainence came look': 1,
#          'came look thermostat': 1,
#          'look thermostat told': 1,
#          'thermostat told play': 1,
#          'told play setting': 1,
#          'play setting happy': 1,
#          'setting happy digital': 1,
#          'happy digital box': 1,
#          'digital box wo': 1,
#          "box wo n't": 1,
#          "wo n't work": 1,
#          "n't work asked": 1,
#          'work asked wakeup': 1,
#          'asked wakeup 10am': 1,
#          'wakeup 10am morning': 1,
#          '10am morning did': 1,
#          "morning did n't": 3,
#          "did n't happen": 5,
#          "n't happen called": 1,
#          'happen called later': 1,
#          'called later 6pm': 1,
#          'later 6pm nap': 1,
#          '6pm nap wakeup': 1,
#          'nap wakeup forgot': 1,
#          'wakeup forgot 10am': 1,
#          'forgot 10am wakeup': 1,
#          '10am wakeup morning': 1,
#          'wakeup morning yep': 1,
#          'morning yep forgotten.the': 1,
#          'yep forgotten.the bathroom': 1,
#          'forgotten.the bathroom facility': 1,
#          'bathroom facility great': 1,
#          'facility great room': 1,
#          'great room surprised': 1,
#          'room surprised room': 1,
#          'surprised room sold': 1,
#          'room sold whirlpool': 1,
#          'sold whirlpool bath': 1,
#          'whirlpool bath tub': 1,
#          "bath tub n't": 1,
#          "tub n't bath": 1,
#          "n't bath amenity": 1,
#          'bath amenity great': 1,
#          'amenity great relax': 1,
#          'great relax water': 1,
#          'relax water jet': 1,
#          'water jet going': 1,
#          'unique great stay': 1,
#          'great stay wonderful': 1,
#          'stay wonderful time': 1,
#          'wonderful time hotel': 1,
#          'time hotel monaco': 1,
#          'hotel monaco location': 1,
#          'monaco location excellent': 1,
#          'location excellent short': 1,
#          'excellent short stroll': 1,
#          'short stroll main': 1,
#          'stroll main downtown': 1,
#          'main downtown shopping': 1,
#          'downtown shopping area': 1,
#          'shopping area pet': 1,
#          'area pet friendly': 1,
#          'pet friendly room': 1,
#          'friendly room showed': 1,
#          'room showed no': 1,
#          'showed no sign': 1,
#          'no sign animal': 1,
#          'sign animal hair': 1,
#          'animal hair smell': 1,
#          'hair smell monaco': 1,
#          'smell monaco suite': 1,
#          'monaco suite sleeping': 1,
#          'suite sleeping area': 1,
#          'sleeping area big': 1,
#          'area big striped': 1,
#          'big striped curtain': 1,
#          'striped curtain pulled': 1,
#          'curtain pulled closed': 1,
#          'pulled closed nice': 1,
#          'closed nice touch': 1,
#          'nice touch felt': 1,
#          'touch felt cosy': 1,
#          'felt cosy goldfish': 1,
#          'cosy goldfish named': 1,
#          'goldfish named brandi': 1,
#          'named brandi enjoyed': 1,
#          'brandi enjoyed did': 1,
#          "enjoyed did n't": 2,
#          "did n't partake": 1,
#          "n't partake free": 1,
#          'partake free wine': 1,
#          'free wine coffee/tea': 1,
#          'wine coffee/tea service': 1,
#          'coffee/tea service lobby': 1,
#          'service lobby thought': 1,
#          'lobby thought great': 1,
#          'thought great feature': 1,
#          'great feature great': 1,
#          'feature great staff': 1,
#          'great staff friendly': 6,
#          'staff friendly free': 3,
#          'friendly free wireless': 1,
#          'free wireless internet': 17,
#          'wireless internet hotel': 2,
#          'internet hotel worked': 1,
#          'hotel worked suite': 1,
#          'worked suite 2': 1,
#          'suite 2 laptop': 1,
#          '2 laptop decor': 1,
#          'laptop decor lovely': 1,
#          'decor lovely eclectic': 1,
#          'lovely eclectic mix': 1,
#          'eclectic mix patten': 1,
#          'mix patten color': 1,
#          'patten color palatte': 1,
#          'color palatte animal': 1,
#          'palatte animal print': 1,
#          'animal print bathrobe': 1,
#          'print bathrobe feel': 1,
#          'bathrobe feel like': 1,
#          'feel like rock': 1,
#          'like rock star': 1,
#          'rock star nice': 1,
#          'star nice did': 1,
#          "nice did n't": 4,
#          "did n't look": 4,
#          "n't look like": 6,
#          'look like sterile': 1,
#          'like sterile chain': 1,
#          'sterile chain hotel': 1,
#          'chain hotel hotel': 2,
#          'hotel hotel personality': 1,
#          'hotel personality excellent': 1,
#          'personality excellent stay': 1,
#          'great stay great': 4,
#          'stay great stay': 2,
#          'great stay went': 2,
#          'stay went seahawk': 1,
#          'went seahawk game': 1,
#          'seahawk game awesome': 1,
#          'game awesome downfall': 1,
#          'awesome downfall view': 1,
#          'downfall view building': 1,
#          'view building did': 1,
#          "building did n't": 1,
#          "did n't complain": 2,
#          "n't complain room": 1,
#          'complain room huge': 1,
#          'room huge staff': 1,
#          'huge staff helpful': 1,
#          'staff helpful booked': 1,
#          'helpful booked hotel': 1,
#          'booked hotel website': 3,
#          'hotel website seahawk': 1,
#          'website seahawk package': 1,
#          'seahawk package no': 1,
#          'package no charge': 1,
#          'no charge parking': 1,
#          'charge parking got': 1,
#          'parking got voucher': 1,
#          'got voucher taxi': 1,
#          'voucher taxi problem': 1,
#          'taxi problem taxi': 1,
#          'problem taxi driver': 1,
#          'taxi driver did': 1,
#          "driver did n't": 2,
#          "did n't want": 17,
#          "n't want accept": 1,
#          'want accept voucher': 1,
#          'accept voucher barely': 1,
#          'voucher barely spoke': 1,
#          'barely spoke english': 1,
#          'spoke english funny': 1,
#          'english funny thing': 1,
#          'funny thing speak': 1,
#          'thing speak arabic': 1,
#          'speak arabic called': 1,
#          'arabic called started': 1,
#          'called started making': 1,
#          'started making comment': 1,
#          'making comment girlfriend': 1,
#          'comment girlfriend cell': 1,
#          'girlfriend cell phone': 1,
#          'cell phone buddy': 1,
#          'phone buddy took': 1,
#          'buddy took second': 1,
#          'took second realize': 1,
#          'second realize just': 1,
#          'realize just said': 1,
#          'just said fact': 1,
#          'said fact speak': 1,
#          'fact speak language': 1,
#          'speak language face': 1,
#          'language face priceless': 1,
#          'face priceless as': 1,
#          'priceless as told': 1,
#          'as told said': 1,
#          'told said large': 1,
#          'said large city': 1,
#          'large city told': 1,
#          'city told head': 1,
#          'told head doorman': 1,
#          'head doorman issue': 1,
#          'doorman issue called': 1,
#          'issue called cab': 1,
#          'called cab company': 1,
#          'cab company promply': 1,
#          'company promply answer': 1,
#          'promply answer did': 1,
#          "answer did n't": 1,
#          "did n't apologized": 1,
#          "n't apologized offered": 1,
#          'apologized offered pay': 1,
#          'offered pay taxi': 1,
#          'pay taxi buck': 1,
#          'taxi buck 2': 1,
#          'buck 2 mile': 1,
#          '2 mile stadium': 1,
#          'mile stadium game': 1,
#          'stadium game plan': 1,
#          'game plan taxi': 1,
#          'plan taxi return': 1,
#          'taxi return going': 1,
#          'return going humpin': 1,
#          'going humpin great': 1,
#          'humpin great walk': 1,
#          'great walk did': 1,
#          "walk did n't": 1,
#          "did n't mind": 5,
#          "n't mind right": 1,
#          'mind right christmas': 1,
#          'right christmas wonderful': 1,
#          'christmas wonderful light': 1,
#          'wonderful light homeless': 1,
#          'light homeless stowed': 1,
#          'homeless stowed away': 1,
#          'stowed away building': 1,
#          'away building entrance': 1,
#          'building entrance leave': 1,
#          'entrance leave police': 1,
#          'leave police presence': 1,
#          'police presence not': 1,
#          'presence not greatest': 1,
#          'not greatest area': 1,
#          'greatest area stadium': 1,
#          'area stadium activity': 1,
#          'stadium activity 7': 1,
#          'activity 7 block': 1,
#          '7 block pike': 1,
#          'block pike street': 1,
#          'pike street waterfront': 1,
#          'street waterfront great': 1,
#          'waterfront great coffee': 1,
#          'great coffee shop': 2,
#          'coffee shop way': 1,
#          'shop way hotel': 1,
#          'way hotel mantained': 1,
#          'hotel mantained foyer': 1,
#          'mantained foyer awesome': 1,
#          'foyer awesome wine': 1,
#          'awesome wine tasting': 1,
#          'wine tasting available': 1,
#          'tasting available evening': 1,
#          'available evening best': 1,
#          'evening best dog': 1,
#          'best dog taking': 1,
#          'dog taking st.': 1,
#          'taking st. bernard': 1,
#          'st. bernard time': 1,
#          'bernard time family': 1,
#          'time family safe': 1,
#          'family safe hotel': 1,
#          'safe hotel located': 1,
#          'hotel located service': 1,
#          'located service desk': 1,
#          'service desk room': 1,
#          'desk room bathroom': 1,
#          'room bathroom huge': 1,
#          'bathroom huge jetted': 1,
#          'huge jetted tub': 1,
#          'jetted tub huge': 1,
#          'tub huge funny': 1,
#          'huge funny house': 1,
#          'funny house keeping': 1,
#          'house keeping walked': 1,
#          'keeping walked girlfriend': 1,
#          'walked girlfriend getting': 1,
#          'girlfriend getting dressed': 1,
#          'getting dressed did': 1,
#          "dressed did n't": 1,
#          "did n't hear": 9,
#          "n't hear knock": 1,
#          'hear knock doing': 1,
#          'knock doing turn': 1,
#          'doing turn service': 1,
#          'turn service screamed': 1,
#          'service screamed girlfriend': 1,
#          'screamed girlfriend scream': 1,
#          'girlfriend scream hit': 1,
#          'scream hit floor': 1,
#          'hit floor laughing': 1,
#          'floor laughing started': 1,
#          'laughing started talking': 1,
#          'started talking spanish': 1,
#          'talking spanish worked': 1,
#          'spanish worked place': 1,
#          'worked place recommend': 1,
#          'place recommend price': 1,
#          'recommend price check': 1,
#          'price check online': 1,
#          'check online deal': 1,
#          'online deal just': 1,
#          'deal just good': 1,
#          'just good not': 1,
#          'not better besite': 1,
#          'better besite contains': 1,
#          'besite contains deal': 1,
#          'contains deal voucher': 1,
#          'deal voucher travel': 1,
#          'voucher travel website': 1,
#          "travel website n't": 1,
#          "website n't tell": 1,
#          'love monaco staff': 1,
#          'monaco staff husband': 1,
#          'staff husband stayed': 2,
#          'husband stayed hotel': 5,
#          'stayed hotel crazy': 1,
#          'hotel crazy weekend': 1,
#          'crazy weekend attending': 1,
#          'weekend attending memorial': 1,
#          'attending memorial service': 1,
#          'memorial service best': 1,
#          'service best friend': 1,
#          'best friend husband': 1,
#          'friend husband celebrating': 1,
#          'husband celebrating 12th': 1,
#          'celebrating 12th wedding': 1,
#          '12th wedding anniversary': 1,
#          'wedding anniversary talk': 1,
#          'anniversary talk mixed': 1,
#          'talk mixed emotion': 1,
#          'mixed emotion booked': 1,
#          'emotion booked suite': 1,
#          'booked suite hotel': 1,
#          'suite hotel monte': 1,
#          'hotel monte carlos': 1,
#          'monte carlos loaned': 1,
#          'carlos loaned beautiful': 1,
#          'loaned beautiful fan-tanned': 1,
#          'beautiful fan-tanned goldfish': 1,
#          'fan-tanned goldfish named': 1,
#          'goldfish named joliet': 1,
#          'named joliet weekend': 1,
#          'joliet weekend visited': 1,
#          'weekend visited dog': 1,
#          'visited dog worked': 1,
#          'dog worked desk': 1,
#          'worked desk human': 1,
#          'desk human companion': 1,
#          'human companion room': 1,
#          'companion room decorated': 1,
#          'room decorated nicely': 2,
#          'decorated nicely couch': 1,
#          'nicely couch used': 1,
#          'couch used pillow': 1,
#          "used pillow l'occitane": 1,
#          "pillow l'occitane bath": 1,
#          "l'occitane bath amenity": 1,
#          'bath amenity welcome': 1,
#          'amenity welcome sight': 1,
#          'welcome sight room': 1,
#          'sight room quiet': 1,
#          'room quiet peaceful': 1,
#          'quiet peaceful wireless': 1,
#          'peaceful wireless internet': 1,
#          'wireless internet access': 9,
#          'internet access wonderful': 1,
#          'access wonderful server': 1,
#          'wonderful server went': 1,
#          'server went morning': 1,
#          'went morning leaving': 1,
#          'morning leaving problem': 1,
#          'leaving problem printing': 1,
#          'problem printing boarding': 1,
#          'printing boarding pass': 2,
#          'boarding pass afternoon': 1,
#          'pass afternoon reception': 1,
#          'afternoon reception serf': 1,
#          'reception serf oenophile-satisfying': 1,
#          'serf oenophile-satisfying wine': 1,
#          'oenophile-satisfying wine australia': 1,
#          'wine australia scrumptious': 1,
#          'australia scrumptious cooky': 1,
#          'scrumptious cooky restaurant': 1,
#          'cooky restaurant closed': 1,
#          'restaurant closed renovation': 1,
#          'closed renovation stay': 1,
#          'renovation stay finally': 1,
#          'stay finally ate': 1,
#          'finally ate food': 1,
#          'ate food good': 1,
#          'food good drink': 1,
#          'good drink better': 1,
#          'drink better word': 1,
#          'better word caution': 1,
#          'word caution restaurant': 1,
#          'caution restaurant larger': 1,
#          'restaurant larger person': 1,
#          'larger person not': 1,
#          'person not sit': 1,
#          'not sit booth': 1,
#          'sit booth wo': 1,
#          "booth wo n't": 1,
#          "wo n't fit": 1,
#          "n't fit 5": 1,
#          'fit 5 6': 1,
#          '5 6 125': 1,
#          '6 125 lb': 1,
#          '125 lb husband': 1,
#          'lb husband 5': 1,
#          'husband 5 9': 1,
#          '5 9 175.': 1,
#          '9 175. table': 1,
#          '175. table smack-against': 1,
#          'table smack-against stomach': 1,
#          'smack-against stomach couple': 1,
#          'stomach couple inch': 1,
#          'couple inch space': 1,
#          'inch space mighty': 1,
#          'space mighty uncomfortable': 1,
#          'mighty uncomfortable patron': 1,
#          'uncomfortable patron larger': 1,
#          'patron larger pregnant': 1,
#          'larger pregnant bad': 1,
#          'pregnant bad design': 1,
#          'bad design opinion': 1,
#          'design opinion place': 1,
#          'opinion place decorated': 1,
#          'place decorated funky': 1,
#          'decorated funky welcoming': 1,
#          'funky welcoming way': 1,
#          'welcoming way metal': 1,
#          'way metal wood': 1,
#          'metal wood handblown': 1,
#          'wood handblown glass': 1,
#          'handblown glass light': 1,
#          'glass light fixture': 1,
#          'light fixture expect': 1,
#          'fixture expect seattle': 1,
#          'expect seattle capital': 1,
#          'seattle capital glass': 1,
#          'capital glass art': 1,
#          'glass art industry': 1,
#          'art industry definitely': 1,
#          'industry definitely stay': 1,
#          'definitely stay reason': 1,
#          'cozy stay rainy': 1,
#          'stay rainy city': 1,
#          'rainy city husband': 1,
#          'city husband spent': 1,
#          'husband spent 7': 1,
#          'spent 7 night': 1,
#          '7 night monaco': 1,
#          'night monaco early': 1,
#          'monaco early january': 1,
#          'early january 2008.': 1,
#          'january 2008. business': 1,
#          '2008. business trip': 1,
#          'business trip chance': 1,
#          'trip chance come': 1,
#          'chance come ride.we': 1,
#          'come ride.we booked': 1,
#          'ride.we booked monte': 1,
#          'booked monte carlo': 1,
#          'monte carlo suite': 1,
#          'carlo suite proved': 1,
#          'suite proved comfortable': 1,
#          'proved comfortable longish': 1,
#          'comfortable longish stay': 1,
#          'longish stay room': 1,
#          'stay room 905': 1,
#          'room 905 located': 1,
#          '905 located street': 1,
#          'located street building': 1,
#          'street building street': 1,
#          'building street noise': 1,
#          'street noise not': 2,
#          'noise not problem': 2,
#          'not problem view': 1,
#          'problem view interesting': 1,
#          'view interesting room': 1,
#          'interesting room building': 1,
#          'room building look': 1,
#          'building look dank': 1,
#          'look dank alley': 1,
#          'dank alley midsection': 1,
#          'alley midsection large': 1,
#          'midsection large office': 1,
#          'large office building': 1,
#          ...})

# %%
# get the feature size
print("3-gram feature size:", len(tri_gram_feat_cnt))

# then, get the sorted features by the frequency
tri_gram_feat_keys = [f for f,cnt in tri_gram_feat_cnt.most_common()]

# draw linear lines and log lines for sorted features
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(range(1, len(tri_gram_feat_cnt)+1), 
        [tri_gram_feat_cnt[f] for f in tri_gram_feat_keys])
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
plt.subplot(1,2,2)
plt.loglog(range(1, len(tri_gram_feat_cnt)+1), 
            [tri_gram_feat_cnt[f] for f in tri_gram_feat_keys],
           basex=10, basey=10)
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
plt.show()
# Out:
# 3-gram feature size: 158822
# <ipython-input-33-ccc0c0b247e6>:15: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(tri_gram_feat_cnt)+1),
# <ipython-input-33-ccc0c0b247e6>:15: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(tri_gram_feat_cnt)+1),

# %% [markdown]
# And 4-gram models.

# %%
# get the feature size
print("4-gram feature size:", len(four_gram_feat_cnt))

# then, get the sorted features by the frequency
four_gram_feat_keys = [f for f,cnt in four_gram_feat_cnt.most_common()]

# draw linear lines and log lines for sorted features
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(range(1, len(four_gram_feat_cnt)+1), 
        [four_gram_feat_cnt[f] for f in four_gram_feat_keys])
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
plt.subplot(1,2,2)
plt.loglog(range(1, len(four_gram_feat_cnt)+1), 
            [four_gram_feat_cnt[f] for f in four_gram_feat_keys],
           basex=10, basey=10)
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
plt.show()
# Out:
# 4-gram feature size: 164792
# <ipython-input-34-9d71c013c57b>:15: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(four_gram_feat_cnt)+1),
# <ipython-input-34-9d71c013c57b>:15: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(four_gram_feat_cnt)+1),

# %% [markdown]
# We can also put them together.

# %%
# draw linear lines and log lines for sorted features
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
# put the four linear lines together
plt.plot(range(1, len(stemmed_feat_cnt)+1),
         [stemmed_feat_cnt[f] for f in stemmed_feat_keys],
         label="stemmed")
plt.plot(range(1, len(bi_gram_feat_cnt)+1),
         [bi_gram_feat_cnt[f] for f in bi_gram_feat_keys],
         label="2-gram")
plt.plot(range(1, len(tri_gram_feat_cnt)+1),
         [tri_gram_feat_cnt[f] for f in tri_gram_feat_keys],
         label="3-gram")
plt.plot(range(1, len(four_gram_feat_cnt)+1),
         [four_gram_feat_cnt[f] for f in four_gram_feat_keys],
         label="4-gram")
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
# show the legend
plt.legend()
plt.subplot(1,2,2)
# put the four log lines together
plt.loglog(range(1, len(stemmed_feat_cnt)+1),
         [stemmed_feat_cnt[f] for f in stemmed_feat_keys],
           basex=10, basey=10, label="stemmed")
plt.loglog(range(1, len(bi_gram_feat_cnt)+1),
         [bi_gram_feat_cnt[f] for f in bi_gram_feat_keys],
           basex=10, basey=10, label="2-gram")
plt.loglog(range(1, len(tri_gram_feat_cnt)+1),
         [tri_gram_feat_cnt[f] for f in tri_gram_feat_keys],
           basex=10, basey=10, label="3-gram")
plt.loglog(range(1, len(four_gram_feat_cnt)+1),
         [four_gram_feat_cnt[f] for f in four_gram_feat_keys],
           basex=10, basey=10, label="4-gram")
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
# show the legend
plt.legend()
plt.show()
# Out:
# <ipython-input-35-54a17b3e51cc>:23: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(stemmed_feat_cnt)+1),
# <ipython-input-35-54a17b3e51cc>:23: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(stemmed_feat_cnt)+1),
# <ipython-input-35-54a17b3e51cc>:26: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(bi_gram_feat_cnt)+1),
# <ipython-input-35-54a17b3e51cc>:26: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(bi_gram_feat_cnt)+1),
# <ipython-input-35-54a17b3e51cc>:29: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(tri_gram_feat_cnt)+1),
# <ipython-input-35-54a17b3e51cc>:29: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(tri_gram_feat_cnt)+1),
# <ipython-input-35-54a17b3e51cc>:32: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(four_gram_feat_cnt)+1),
# <ipython-input-35-54a17b3e51cc>:32: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.loglog(range(1, len(four_gram_feat_cnt)+1),

# %% [markdown]
# As we can see, linear lines are not suitable to analyze. From the log view, we can find more than 80% features are low-frequent.
# And only about 3000 features occur no less than 10 times.

# %%
print("stemmed features > 10:",
      len([f for f, cnt in stemmed_feat_cnt.items() if cnt > 10]))
print("2-gram features > 10:",
      len([f for f, cnt in bi_gram_feat_cnt.items() if cnt > 10]))
print("3-gram features > 10:",
      len([f for f, cnt in tri_gram_feat_cnt.items() if cnt > 10]))
print("4-gram features > 10:",
      len([f for f, cnt in four_gram_feat_cnt.items() if cnt > 10]))
# Out:
# stemmed features > 10: 1939
# 2-gram features > 10: 1017
# 3-gram features > 10: 93
# 4-gram features > 10: 4

# %% [markdown]
# And we can check the top 10 features.

# %%
print("stemmed features top 10:",
      stemmed_feat_keys[:10])
print("2-gram features top 10:",
      bi_gram_feat_keys[:10])
print("3-gram features top 10:",
      tri_gram_feat_keys[:10])
print("4-gram features top 10:",
      four_gram_feat_keys[:10])
# Out:
# stemmed features top 10: ['hotel', 'room', 'great', 'stay', "n't", 'staff', 'location', 'night', 'nice', 'good']
# 2-gram features top 10: ["did n't", 'san francisco', 'did not', 'great location', 'staff friendly', 'room clean', 'union square', "ca n't", 'walking distance', 'great hotel']
# 3-gram features top 10: ['staff friendly helpful', 'pike place market', 'hotel great location', 'great place stay', "ca n't beat", 'great hotel great', 'did not work', 'flat screen tv', 'hotel staff friendly', 'staff helpful friendly']
# 4-gram features top 10: ['great hotel great location', 'block pike place market', "ca n't beat location", 'staff friendly helpful room', "location ca n't beat", 'staff extremely friendly helpful', 'walking distance pike place', 'room 2 double bed', 'union square cable car', 'great location great hotel']

# %% [markdown]
# ## Cross Validation and Ensemble

# %% [markdown]
# We can use cross validation with the ensemble technique to reduce overfitting as well as the randomness issue.

# %%
# n_fold document: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html
n_fold = 3
np.random.seed(0)
# create the n-fold generator
skf = StratifiedKFold(n_fold, shuffle=True)

clfs_1 = list()
valid_acc_list = list()
for k, (train_idx, valid_idx) in enumerate(
    skf.split(train_feats_matrix.toarray(), train_labels)):
    # build the classifier and train
    clf = GaussianNB()
    
    clf.fit(train_feats_matrix.toarray()[train_idx], train_labels.values[train_idx])
    
    #Get the predictions of the classifier
    train_pred = clf.predict(train_feats_matrix.toarray()[train_idx])
    valid_pred = clf.predict(train_feats_matrix.toarray()[valid_idx])

    #Compute accuracy scores
    train_score = accuracy_score(train_labels.values[train_idx], train_pred)
    valid_score = accuracy_score(train_labels.values[valid_idx], valid_pred)
    
    print("training accuracy", train_score)
    print("validation accuracy", valid_score)
    
    clfs_1.append(clf)
    valid_acc_list.append(valid_score)
    
print('Average validation score: ', sum(valid_acc_list)/len(valid_acc_list))
# Out:
# training accuracy 0.8612153038259565
# validation accuracy 0.4452773613193403
# training accuracy 0.8582145536384096
# validation accuracy 0.41679160419790107
# training accuracy 0.8643178410794603
# validation accuracy 0.40540540540540543
# Average validation score:  0.4224914569742156

# %% [markdown]
# We can try another model with different input features

# %%
# build a set containing each unique feature which has appeared more than 10 times in the training set
new_feats_set = set()

# add those stem features which occurs more than 10 times into the feature set.
new_feats_set.update([f for f, cnt in stemmed_feat_cnt.items() if cnt > 10]) 
    
# add those 2-gram features which occurs more than 10 times into the feature set.
new_feats_set.update([f for f, cnt in bi_gram_feat_cnt.items() if cnt > 10]) 

print("Size of new features:", len(new_feats_set))
# build a mapping from features to indices
new_feats_dict = dict(zip(new_feats_set, range(len(new_feats_set))))

# build the feature list
new_train_feats = list()
for i in range(len(train_ids)):
    # concatenate the stemmed token list and the 2_gram list together
    new_train_feats.append(train_stemmed[i] + train_2_gram[i] )
new_test_feats = list()
for i in range(len(test_ids)):
    # concatenate the stemmed token list and the 2_gram list together
    new_test_feats.append(test_stemmed[i] + test_2_gram[i])

# build the feats_matrix in a similar way as described above
new_train_feats_matrix = coo_matrix(np.vstack([get_onehot_vector(f, new_feats_dict) for f in new_train_feats]))
new_test_feats_matrix = coo_matrix(np.vstack([get_onehot_vector(f, new_feats_dict) for f in new_test_feats]))
# Out:
# Size of new features: 2956

# %%
n_fold = 3
# create the n-fold generator
skf = StratifiedKFold(n_fold, shuffle=True)

clfs_2 = list()
valid_acc_list = list()

for k, (train_idx, valid_idx) in enumerate(
    skf.split(new_train_feats_matrix.toarray(), train_labels)):
    # build the classifier and train
    clf = GaussianNB()
    
    clf.fit(new_train_feats_matrix.toarray()[train_idx], train_labels.values[train_idx])
    
    #Get the predictions of the classifier
    train_pred = clf.predict(new_train_feats_matrix.toarray()[train_idx])
    valid_pred = clf.predict(new_train_feats_matrix.toarray()[valid_idx])

    #Compute accuracy scores
    train_score = accuracy_score(train_labels.values[train_idx], train_pred)
    valid_score = accuracy_score(train_labels.values[valid_idx], valid_pred)
    
    print("training accuracy", train_score)
    print("validation accuracy", valid_score)
    
    clfs_2.append(clf)
    valid_acc_list.append(valid_score)
    
print('Average validation score: ', sum(valid_acc_list)/len(valid_acc_list))
# Out:
# training accuracy 0.8589647411852963
# validation accuracy 0.41529235382308843
# training accuracy 0.8777194298574643
# validation accuracy 0.4032983508245877
# training accuracy 0.8710644677661169
# validation accuracy 0.42492492492492495
# Average validation score:  0.4145052098575337

# %% [markdown]
# Since the classifier with the first type of features has better validation score, we choose to do the ensemble on the corresponding instances.

# %%
# compute the sum of test probabilities and return the classes with largest sums
test_prob = None
for i, clf in enumerate(clfs_1):
    if(i==0):
        test_prob = clf.predict_proba(test_feats_matrix.toarray())
    else:
        test_prob += clf.predict_proba(test_feats_matrix.toarray())
        
test_pred = test_prob.argmax(axis=1) + 1
print("Ensemble", "test accuracy", accuracy_score(test_labels, test_pred))
# Out:
# Ensemble test accuracy 0.4425

# %% [markdown]
# Summary of Tutorial
#
# 1) Tokenize
# 2) Lemmatize
# 3) Remove stop words
# 4) Create n-grams
# 5) Select features that occur more than 10 times
# 6) Keep a feature set that is updated with the tokens and n-grams
# 7) Combine the tokens and n-grams
# 8) Create a one hot vector for each document and vertically stack it
# 9) Train a classifier on it
